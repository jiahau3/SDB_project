# %% [markdown]
# # Exploring vector data and finding bounding boxes

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import geopandas as gpd

from shapely.geometry import box

# %% [markdown]
# In this exploration I wanted to start with the extent and the location of the Lago Patillas because I have a good bathymetry map for it. How to come to this data and how you would create a high-quality bathymetry map from survey data [here](https://hatarilabs.com/ih-en/how-to-make-a-lake-bathymetric-map-with-qgis-tutorial).

# %%
patillas_shoreline = gpd.read_file('../data/patillas_sample/vector/patillas_shoreline.shp')
patillas_shoreline
# Out:
#    OBJECTID  contour_m    Shape_Leng    Shape_Area  \
# 0       1.0  67.550003  21828.075344  1.203714e+06
#
#                                             geometry
# 0  POLYGON ((242914.395 221850.983, 242914.450 22...

# %% [markdown]
# One of the reasons I work with GeoPandas is that it know how to work with geographical data. For instance it knows how to handle CRS information which helps when switching between different projections.

# %%
patillas_shoreline.crs
# Out:
# <Projected CRS: EPSG:6566>
# Name: NAD83(2011) / Puerto Rico and Virgin Is.
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Puerto Rico and US Virgin Islands - onshore.
# - bounds: (-67.97, 17.62, -64.51, 18.57)
# Coordinate Operation:
# - name: SPCS83 Puerto Rico & Virgin Islands zone (meters)
# - method: Lambert Conic Conformal (2SP)
# Datum: NAD83 (National Spatial Reference System 2011)
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# Also, GeoPandas has easy to use interfaces for plotting.

# %%
_, ax = plt.subplots(figsize=(10, 10))
patillas_shoreline.plot(ax=ax)
plt.show()

# %%
patillas_shoreline.bounds
# Out:
#           minx         miny         maxx         maxy
# 0  242404.8444  220437.1921  244768.1377  221851.1084

# %% [markdown]
# I created a little helper function to get a simple box geometry around all the elements within a geopandas frame. I use this because querying the sentinel API shouldn't be done with an easy "footprint" (not too many nodes in the geometry).

# %%
def get_bounding_box(gpd_object, buffer_size=0):
    """
    Returns the bounding box of a geopandas object

    Parameters
    ----------
    gpd_object : geopandas object
        The geopandas object to get the bounding box of
    buffer_size : int
        The buffer size to add to the bounding box

    Returns
    -------
    bounding_box : geopandas series
        The bounding box of the geopandas object
    """
    minx, miny, maxx, maxy = gpd_object.bounds.values.ravel().tolist()
    minx, miny, maxx, maxy = minx - buffer_size, miny - buffer_size, maxx + buffer_size, maxy + buffer_size
    bounding_poly = box(minx, miny, maxx, maxy)
    bounding_series = gpd.GeoSeries([bounding_poly], crs=gpd_object.crs)

    return bounding_series

# %%
bounding_box = get_bounding_box(patillas_shoreline, buffer_size=100)

_, ax = plt.subplots(figsize=(10, 10))
bounding_box.plot(ax=ax, color="red")
patillas_shoreline.plot(ax=ax)
plt.show()

# %% [markdown]
# # Exploring bathymetry map

# %%
import rasterio as rio
from rasterio.plot import plotting_extent

import earthpy as et
import earthpy.plot as ep
import earthpy.spatial as es

# %% [markdown]
# The already existing hiqh-quality bathymetry map can be explored using rasterio.

# %%
with rio.open('../data/patillas_sample/raster/lake_depth.tif') as src:
    bathymetry_map = src.read(masked=True)[0]
    extent = plotting_extent(src)
    soap_profile = src.profile

# %%
ep.plot_bands(bathymetry_map,
               cmap='Blues',
               extent=extent,
               cbar=True);

# %% [markdown]
# # Searching sentinel data for Lago Patillas

# %%
import folium
import getpass
import json
import glob

import sentinelsat as sat
from sentinelsat import SentinelAPI, make_path_filter

# %% [markdown]
# I chose to visualize the area of interest with folium. The interactive map helps me to compare survey regions with what I get from sentinel. I had to transform the CRS of the bounding box centroid because folium uses ellipsoidal coordinates which are different from the northings/eastings values I have in my current projection.

# %%
lat_long_centroid = bounding_box.centroid.to_crs(epsg=4326)
x, y = lat_long_centroid.x, lat_long_centroid.y
m = folium.Map([y, x], zoom_start=16)
folium.GeoJson(bounding_box.to_crs(epsg=4326).to_json()).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_19893ca793b04bf4b59d1b4cb1b47ce2%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_19893ca793b04bf4b59d1b4cb1b47ce2%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_19893ca793b04bf4b59d1b4cb1b47ce2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_19893ca793b04bf4b59d1b4cb1b47ce2%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B18.02392843106244%2C%20-66.02171544251114%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# The following cells are used to construct the Copernicus Sentinel API client and query the service requesting data with a footprint corresponding to Lago Patillas and a cloud cover percentage of 10% at max. As most of the swaths are over the ocean this percentage is unfortunately not entirely useful as even a little cloud cover is usually covering the land rather than the water.

# %%
copernicus_user = getpass.getpass("Enter your Copernicus username: ")

# %%
copernicus_password = getpass.getpass("Enter your Copernicus password: ")

# %%
api = SentinelAPI(copernicus_user, copernicus_password, 'https://scihub.copernicus.eu/dhus')

# %%
footprint = sat.geojson_to_wkt(json.loads(bounding_box.to_crs(epsg=4326).to_json()))
footprint
# Out:
# 'GEOMETRYCOLLECTION(POLYGON((-66.0096 18.0166,-66.0096 18.0312,-66.0338 18.0312,-66.0338 18.0167,-66.0096 18.0166)))'

# %%
products = api.query(footprint,
                     date = ('20210801', '20211104'),
                     platformname = 'Sentinel-2',
                     processinglevel = 'Level-2A',
                     cloudcoverpercentage = (0, 10))

# %% [markdown]
# The cells below look at all the products corresponding to the search criteria. They usually cover two areas at different times. Going back further than a couple of months in time would hit the long time archive which only becomes available after a couple of hours after being triggered.

# %%
areas = api.to_geodataframe(products)
areas.plot(column='uuid', cmap=None)
# Out:
# <AxesSubplot:>

# %%
ax = areas.plot(column='uuid', cmap=None, figsize=(10, 10))
areas.apply(lambda x: ax.annotate(text=x.uuid, xy=x.geometry.centroid.coords[0], ha='center'),axis=1)
# Out:
# 6245d659-c46b-493c-8e8e-830367ce6630    Annotation(-65.7708, 17.5889, '6245d659-c46b-4...
# 9610ac11-ef81-4127-a785-96d05dfe795b    Annotation(-65.6622, 18.4798, '9610ac11-ef81-4...
# 1afde1e5-ed24-4836-9b37-ca613bcfbc69    Annotation(-65.6617, 18.4796, '1afde1e5-ed24-4...
# 26806b42-5c4d-4232-8b99-fce76993d241    Annotation(-65.77, 17.5889, '26806b42-5c4d-423...
# cd4bd80a-86da-48dc-a378-c59f35963aef    Annotation(-65.6594, 18.4786, 'cd4bd80a-86da-4...
# 4488a088-dc6d-4e23-af4c-972cc77e53b8    Annotation(-65.7663, 17.5887, '4488a088-dc6d-4...
# c9d8d1fd-3344-48cb-bc32-52f4b13dde4b    Annotation(-65.6593, 18.4785, 'c9d8d1fd-3344-4...
# 8cf4ef49-479c-423a-96d1-d554519dac06    Annotation(-65.7658, 17.5886, '8cf4ef49-479c-4...
# e8107b74-4d70-4e7a-8598-0eb71b538b6d    Annotation(-65.6581, 18.478, 'e8107b74-4d70-4e...
# 34ca3b2c-aa7e-49ae-8576-f739c6a3bba8    Annotation(-65.7638, 17.5885, '34ca3b2c-aa7e-4...
# 2ea11cfa-a456-47ea-9d5f-3e69f72c0245    Annotation(-65.7631, 17.5884, '2ea11cfa-a456-4...
# 6a88b496-5868-4aa7-9924-8b71915f05a2    Annotation(-65.764, 17.5885, '6a88b496-5868-4a...
# dtype: object

# %%
_, ax = plt.subplots(1, figsize=(10, 10))
areas.plot(ax=ax,column='uuid', cmap=None,)
bounding_box.to_crs(epsg=4326).plot(ax=ax)
plt.show()

# %%
areas.sort_values(by='cloudcoverpercentage', ascending=False)[["title", "link", "cloudcoverpercentage"]]
# Out:
#                                                                                   title  \
# 2ea11cfa-a456-47ea-9d5f-3e69f72c0245  S2B_MSIL2A_20210820T150719_N0301_R082_T19QHV_2...
# cd4bd80a-86da-48dc-a378-c59f35963aef  S2B_MSIL2A_20210929T150719_N0301_R082_T19QHA_2...
# 4488a088-dc6d-4e23-af4c-972cc77e53b8  S2B_MSIL2A_20210929T150719_N0301_R082_T19QHV_2...
# 1afde1e5-ed24-4836-9b37-ca613bcfbc69  S2B_MSIL2A_20211019T150719_N0301_R082_T19QHA_2...
# e8107b74-4d70-4e7a-8598-0eb71b538b6d  S2A_MSIL2A_20210825T150721_N0301_R082_T19QHA_2...
# 9610ac11-ef81-4127-a785-96d05dfe795b  S2B_MSIL2A_20211029T150719_N0301_R082_T19QHA_2...
# 6245d659-c46b-493c-8e8e-830367ce6630  S2B_MSIL2A_20211029T150719_N0301_R082_T19QHV_2...
# 6a88b496-5868-4aa7-9924-8b71915f05a2  S2A_MSIL2A_20210805T150721_N0301_R082_T19QHV_2...
# 26806b42-5c4d-4232-8b99-fce76993d241  S2B_MSIL2A_20211019T150719_N0301_R082_T19QHV_2...
# c9d8d1fd-3344-48cb-bc32-52f4b13dde4b  S2A_MSIL2A_20210924T150721_N0301_R082_T19QHA_2...
# 8cf4ef49-479c-423a-96d1-d554519dac06  S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_2...
# 34ca3b2c-aa7e-49ae-8576-f739c6a3bba8  S2A_MSIL2A_20210825T150721_N0301_R082_T19QHV_2...
#
#                                                                                    link  \
# 2ea11cfa-a456-47ea-9d5f-3e69f72c0245  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
# cd4bd80a-86da-48dc-a378-c59f35963aef  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
# 4488a088-dc6d-4e23-af4c-972cc77e53b8  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
# 1afde1e5-ed24-4836-9b37-ca613bcfbc69  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
# e8107b74-4d70-4e7a-8598-0eb71b538b6d  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
# 9610ac11-ef81-4127-a785-96d05dfe795b  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
# 6245d659-c46b-493c-8e8e-830367ce6630  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
# 6a88b496-5868-4aa7-9924-8b71915f05a2  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
# 26806b42-5c4d-4232-8b99-fce76993d241  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
# c9d8d1fd-3344-48cb-bc32-52f4b13dde4b  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
# 8cf4ef49-479c-423a-96d1-d554519dac06  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
# 34ca3b2c-aa7e-49ae-8576-f739c6a3bba8  https://scihub.copernicus.eu/dhus/odata/v1/Pro...
#
#                                       cloudcoverpercentage
# 2ea11cfa-a456-47ea-9d5f-3e69f72c0245              8.800548
# cd4bd80a-86da-48dc-a378-c59f35963aef              7.544889
# 4488a088-dc6d-4e23-af4c-972cc77e53b8              7.517684
# 1afde1e5-ed24-4836-9b37-ca613bcfbc69              7.227406
# e8107b74-4d70-4e7a-8598-0eb71b538b6d              6.556714
# 9610ac11-ef81-4127-a785-96d05dfe795b              5.353596
# 6245d659-c46b-493c-8e8e-830367ce6630              5.079897
# 6a88b496-5868-4aa7-9924-8b71915f05a2              5.051208
# 26806b42-5c4d-4232-8b99-fce76993d241              4.211897
# c9d8d1fd-3344-48cb-bc32-52f4b13dde4b              3.519006
# 8cf4ef49-479c-423a-96d1-d554519dac06              3.319633
# 34ca3b2c-aa7e-49ae-8576-f739c6a3bba8              2.765924

# %% [markdown]
# After the inspection of a couple of possible products I found one that shows Lago Patillas without being covered by clouds. I still have to find a better way to check for cloud cover over a very tiny area in the whole footprint of a sentinel data product.

# %%
# min_cloudcover_id = areas["cloudcoverpercentage"].idxmin() # we can extract the image with the minimum cloud cover like this
min_cloudcover_id = "8cf4ef49-479c-423a-96d1-d554519dac06" # unfortunately most of the image is water and clouds are over land so we have to visually inspect
nodefilter = make_path_filter("*_B0[2348]_10m.jp2") # for now we only want the 10x10m resolution bands
product_info = api.download(min_cloudcover_id, directory_path='../data/patillas_sample/sentinel/', nodefilter=nodefilter)
product_info
# Out:
# Downloading T19QHV_20210924T150721_B02_10m.jp2: 100%|██████████| 107M/107M [01:07<00:00, 1.58MB/s]
# Downloading T19QHV_20210924T150721_B03_10m.jp2: 100%|██████████| 106M/106M [01:27<00:00, 1.21MB/s]
# {'id': '8cf4ef49-479c-423a-96d1-d554519dac06',
#  'title': 'S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527',
#  'size': 907600826,
#  'md5': '636eb8e5eda1c44dc8d229ce552eb580',
#  'date': datetime.datetime(2021, 9, 24, 15, 7, 21, 24000),
#  'footprint': 'POLYGON((-65.24338 18.052236150133126,-65.25955 17.98588940240246,-65.295654 17.83780512190609,-65.33176 17.689657249475857,-65.36789 17.541429314118698,-65.40402 17.393111665036663,-65.440094 17.244739647668133,-65.476135 17.096319784403327,-65.48358 17.065512161929828,-66.18158 17.076990254953255,-66.16617 18.068262213544536,-65.24338 18.052236150133126))',
#  'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/$value",
#  'Online': True,
#  'Creation Date': datetime.datetime(2021, 9, 24, 23, 5, 11, 210000),
#  'Ingestion Date': datetime.datetime(2021, 9, 24, 23, 4, 2, 162000),
#  'quicklook_url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/Products('Quicklook')/$value",
#  'node_path': './S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE',
#  'nodes': {'./manifest.safe': {'id': '8cf4ef49-479c-423a-96d1-d554519dac06',
#    'title': 'S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527',
#    'size': 96428,
#    'date': datetime.datetime(2021, 9, 24, 15, 7, 21, 24000),
#    'footprint': 'POLYGON((-65.24338 18.052236150133126,-65.25955 17.98588940240246,-65.295654 17.83780512190609,-65.33176 17.689657249475857,-65.36789 17.541429314118698,-65.40402 17.393111665036663,-65.440094 17.244739647668133,-65.476135 17.096319784403327,-65.48358 17.065512161929828,-66.18158 17.076990254953255,-66.16617 18.068262213544536,-65.24338 18.052236150133126))',
#    'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/Nodes('S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE')/Nodes('manifest.safe')/$value",
#    'Online': True,
#    'Creation Date': datetime.datetime(2021, 9, 24, 23, 5, 11, 210000),
#    'Ingestion Date': datetime.datetime(2021, 9, 24, 23, 4, 2, 162000),
#    'quicklook_url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/Products('Quicklook')/$value",
#    'node_path': './manifest.safe'},
#   './GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B02_10m.jp2': {'id': '8cf4ef49-479c-423a-96d1-d554519dac06',
#    'title': 'S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527',
#    'size': 107433740,
#    'md5': '636eb8e5eda1c44dc8d229ce552eb580',
#    'date': datetime.datetime(2021, 9, 24, 15, 7, 21, 24000),
#    'footprint': 'POLYGON((-65.24338 18.052236150133126,-65.25955 17.98588940240246,-65.295654 17.83780512190609,-65.33176 17.689657249475857,-65.36789 17.541429314118698,-65.40402 17.393111665036663,-65.440094 17.244739647668133,-65.476135 17.096319784403327,-65.48358 17.065512161929828,-66.18158 17.076990254953255,-66.16617 18.068262213544536,-65.24338 18.052236150133126))',
#    'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/Nodes('S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE')/Nodes('GRANULE')/Nodes('L2A_T19QHV_A032683_20210924T150723')/Nodes('IMG_DATA')/Nodes('R10m')/Nodes('T19QHV_20210924T150721_B02_10m.jp2')/$value",
#    'Online': True,
#    'Creation Date': datetime.datetime(2021, 9, 24, 23, 5, 11, 210000),
#    'Ingestion Date': datetime.datetime(2021, 9, 24, 23, 4, 2, 162000),
#    'quicklook_url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/Products('Quicklook')/$value",
#    'node_path': './GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B02_10m.jp2',
#    'nodes': {...},
#    'sha3-256': '873E865E79DD70A4C02726D320FB4AF86FD749571C7C16B4E049D730E0C483A2',
#    'path': WindowsPath('C:/Users/grego/source/repos/Glintsolar/preprocessing/data/patillas_sample/sentinel/S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE/GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B02_10m.jp2'),
#    'downloaded_bytes': 107433740},
#   './GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B03_10m.jp2': {'id': '8cf4ef49-479c-423a-96d1-d554519dac06',
#    'title': 'S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527',
#    'size': 106061904,
#    'md5': '636eb8e5eda1c44dc8d229ce552eb580',
#    'date': datetime.datetime(2021, 9, 24, 15, 7, 21, 24000),
#    'footprint': 'POLYGON((-65.24338 18.052236150133126,-65.25955 17.98588940240246,-65.295654 17.83780512190609,-65.33176 17.689657249475857,-65.36789 17.541429314118698,-65.40402 17.393111665036663,-65.440094 17.244739647668133,-65.476135 17.096319784403327,-65.48358 17.065512161929828,-66.18158 17.076990254953255,-66.16617 18.068262213544536,-65.24338 18.052236150133126))',
#    'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/Nodes('S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE')/Nodes('GRANULE')/Nodes('L2A_T19QHV_A032683_20210924T150723')/Nodes('IMG_DATA')/Nodes('R10m')/Nodes('T19QHV_20210924T150721_B03_10m.jp2')/$value",
#    'Online': True,
#    'Creation Date': datetime.datetime(2021, 9, 24, 23, 5, 11, 210000),
#    'Ingestion Date': datetime.datetime(2021, 9, 24, 23, 4, 2, 162000),
#    'quicklook_url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/Products('Quicklook')/$value",
#    'node_path': './GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B03_10m.jp2',
#    'nodes': {...},
#    'sha3-256': '6562E6BF123655DEE1182C1DBA968BA4E0AD071F8EC134644DFE8DA30D126DB9',
#    'path': WindowsPath('C:/Users/grego/source/repos/Glintsolar/preprocessing/data/patillas_sample/sentinel/S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE/GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B03_10m.jp2'),
#    'downloaded_bytes': 106061904},
#   './GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B04_10m.jp2': {'id': '8cf4ef49-479c-423a-96d1-d554519dac06',
#    'title': 'S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527',
#    'size': 103587209,
#    'md5': '636eb8e5eda1c44dc8d229ce552eb580',
#    'date': datetime.datetime(2021, 9, 24, 15, 7, 21, 24000),
#    'footprint': 'POLYGON((-65.24338 18.052236150133126,-65.25955 17.98588940240246,-65.295654 17.83780512190609,-65.33176 17.689657249475857,-65.36789 17.541429314118698,-65.40402 17.393111665036663,-65.440094 17.244739647668133,-65.476135 17.096319784403327,-65.48358 17.065512161929828,-66.18158 17.076990254953255,-66.16617 18.068262213544536,-65.24338 18.052236150133126))',
#    'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/Nodes('S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE')/Nodes('GRANULE')/Nodes('L2A_T19QHV_A032683_20210924T150723')/Nodes('IMG_DATA')/Nodes('R10m')/Nodes('T19QHV_20210924T150721_B04_10m.jp2')/$value",
#    'Online': True,
#    'Creation Date': datetime.datetime(2021, 9, 24, 23, 5, 11, 210000),
#    'Ingestion Date': datetime.datetime(2021, 9, 24, 23, 4, 2, 162000),
#    'quicklook_url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/Products('Quicklook')/$value",
#    'node_path': './GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B04_10m.jp2',
#    'nodes': {...},
#    'sha3-256': '2DAEB88A60151B2B2AD2AB88EAE7BA1F8866D22BAABC9DE8C61141ED791BD96A',
#    'path': WindowsPath('C:/Users/grego/source/repos/Glintsolar/preprocessing/data/patillas_sample/sentinel/S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE/GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B04_10m.jp2'),
#    'downloaded_bytes': 0},
#   './GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B08_10m.jp2': {'id': '8cf4ef49-479c-423a-96d1-d554519dac06',
#    'title': 'S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527',
#    'size': 101915325,
#    'md5': '636eb8e5eda1c44dc8d229ce552eb580',
#    'date': datetime.datetime(2021, 9, 24, 15, 7, 21, 24000),
#    'footprint': 'POLYGON((-65.24338 18.052236150133126,-65.25955 17.98588940240246,-65.295654 17.83780512190609,-65.33176 17.689657249475857,-65.36789 17.541429314118698,-65.40402 17.393111665036663,-65.440094 17.244739647668133,-65.476135 17.096319784403327,-65.48358 17.065512161929828,-66.18158 17.076990254953255,-66.16617 18.068262213544536,-65.24338 18.052236150133126))',
#    'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/Nodes('S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE')/Nodes('GRANULE')/Nodes('L2A_T19QHV_A032683_20210924T150723')/Nodes('IMG_DATA')/Nodes('R10m')/Nodes('T19QHV_20210924T150721_B08_10m.jp2')/$value",
#    'Online': True,
#    'Creation Date': datetime.datetime(2021, 9, 24, 23, 5, 11, 210000),
#    'Ingestion Date': datetime.datetime(2021, 9, 24, 23, 4, 2, 162000),
#    'quicklook_url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cf4ef49-479c-423a-96d1-d554519dac06')/Products('Quicklook')/$value",
#    'node_path': './GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B08_10m.jp2',
#    'nodes': {...},
#    'sha3-256': '8D4E42A061BFC5E76AB23FE1BEDDE797BE0C7EA547CC709B835049E3F1279E28',
#    'path': WindowsPath('C:/Users/grego/source/repos/Glintsolar/preprocessing/data/patillas_sample/sentinel/S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE/GRANULE/L2A_T19QHV_A032683_20210924T150723/IMG_DATA/R10m/T19QHV_20210924T150721_B08_10m.jp2'),
#    'downloaded_bytes': 0}}}

# %% [markdown]
# # Exploring, stacking, cropping and exporting sentinel data to a single geoTIFF

# %% [markdown]
# In this part I take the acquired raw data and try to stack all bands to get one image and crop everything away that isn't part of the area of interest. In the end, only the area of interest should stay and be accessible in a single multi-band geoTIFF.

# %%
r10m_base = r"..\data\patillas_sample\sentinel\S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE\GRANULE\L2A_T19QHV_A032683_20210924T150723\IMG_DATA\R10m"
r10m_globbing_pattern = f"{r10m_base}/*.jp2"
stack_band_paths = glob.glob(r10m_globbing_pattern)
stack_band_paths.sort()
stack_band_paths
# Out:
# ['..\\data\\patillas_sample\\sentinel\\S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE\\GRANULE\\L2A_T19QHV_A032683_20210924T150723\\IMG_DATA\\R10m\\T19QHV_20210924T150721_B02_10m.jp2',
#  '..\\data\\patillas_sample\\sentinel\\S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE\\GRANULE\\L2A_T19QHV_A032683_20210924T150723\\IMG_DATA\\R10m\\T19QHV_20210924T150721_B03_10m.jp2',
#  '..\\data\\patillas_sample\\sentinel\\S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE\\GRANULE\\L2A_T19QHV_A032683_20210924T150723\\IMG_DATA\\R10m\\T19QHV_20210924T150721_B04_10m.jp2',
#  '..\\data\\patillas_sample\\sentinel\\S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE\\GRANULE\\L2A_T19QHV_A032683_20210924T150723\\IMG_DATA\\R10m\\T19QHV_20210924T150721_B08_10m.jp2']

# %%
array, raster_prof = es.stack(stack_band_paths, out_path=r"..\data\patillas_sample\sentinel\S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE\stacked\raster.jp2")
raster_prof
# Out:
# {'driver': 'JP2OpenJPEG', 'dtype': 'uint16', 'nodata': None, 'width': 10980, 'height': 10980, 'count': 4, 'crs': CRS.from_epsg(32619), 'transform': Affine(10.0, 0.0, 799980.0,
#        0.0, -10.0, 2000040.0), 'blockxsize': 1024, 'blockysize': 1024, 'tiled': True, 'interleave': 'pixel'}

# %%
extent = plotting_extent(array[0], raster_prof["transform"])
extent
# Out:
# (799980.0, 909780.0, 1890240.0, 2000040.0)

# %% [markdown]
# In the following plot we can see, that most of the satellite image shows the ocean. Fortunately it seems that our area of interest is cloud free.

# %%
fig, ax = plt.subplots(figsize=(12, 12))
ep.plot_rgb(
    array,
    rgb=[2, 1, 0],
    ax=ax,
    stretch=True,
    extent=extent,
    str_clip=0.5
)
plt.show()

# %% [markdown]
# We are only really interested in the Lago Patillas. Because I we have the shape of the shore outline we know the exact extends and can use this as the crop bounds. We make sure to force the CRS of the crop bounds to be the same as of the satellite images to not run into errors.

# %%
with rio.open(stack_band_paths[0]) as raster_crs:
    crop_raster_profile = raster_crs.profile
    crop_bound_projected = patillas_shoreline.to_crs(crop_raster_profile["crs"])

crop_bound_projected
# Out:
#    OBJECTID  contour_m    Shape_Leng    Shape_Area  \
# 0       1.0  67.550003  21828.075344  1.203714e+06
#
#                                             geometry
# 0  POLYGON ((814679.686 1996068.635, 814679.743 1...

# %%
crop_output_dir = r"..\data\patillas_sample\sentinel\S2A_MSIL2A_20210924T150721_N0301_R082_T19QHV_20210924T192527.SAFE\cropped"

band_paths_list = es.crop_all(
    stack_band_paths, crop_output_dir, crop_bound_projected, overwrite=True
)

# %% [markdown]
# After cropping we can stack the cropped bands again and plot the stacked image with the overlayed outline.

# %%
cropped_array, array_raster_profile = es.stack(band_paths_list)
crop_extent = plotting_extent(
    cropped_array[0], array_raster_profile["transform"]
)

# Plotting the cropped image
fig, ax = plt.subplots(figsize=(12, 6))
crop_bound_projected.boundary.plot(ax=ax, color="red", zorder=10)
ep.plot_rgb(
    cropped_array,
    rgb=[2, 1, 0],
    ax=ax,
    stretch=True,
    extent=crop_extent
)
plt.show()

# %% [markdown]
# If we're happy at this point we can export the data.

# %%
with rio.open("../data/patillas_sample/raster/patillas_sentinel_l2a_r10m.tif", "w", **array_raster_profile) as dst:
    dst.write(cropped_array)
